# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Frames

# %%
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df = pd.DataFrame(data, columns=columns)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# **we can also use list of dictionary to create dataframe**

# %%
data = [
    {
        "Make": "Nissan",
        "Model": "Stanza",
        "Year": 1991,
        "Engine HP": 138.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "sedan",
        "MSRP": 2000
    },
    {
        "Make": "Hyundai",
        "Model": "Sonata",
        "Year": 2017,
        "Engine HP": None,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "Sedan",
        "MSRP": 27150
    },
    {
        "Make": "Lotus",
        "Model": "Elise",
        "Year": 2010,
        "Engine HP": 218.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "convertible",
        "MSRP": 54990
    },
    {
        "Make": "GMC",
        "Model": "Acadia",
        "Year": 2017,
        "Engine HP": 194.0,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "4dr SUV",
        "MSRP": 34450
    },
    {
        "Make": "Nissan",
        "Model": "Frontier",
        "Year": 2017,
        "Engine HP": 261.0,
        "Engine Cylinders": 6,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "Pickup",
        "MSRP": 32340
    }
]

# %%
pd.DataFrame(data)
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(n=3)
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990

# %% [markdown]
# # Series

# %%
df.Make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['Make']
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['Engine HP']   #to access columns having spaces
# Out:
# 0    138.0
# 1      NaN
# 2    218.0
# 3    194.0
# 4    261.0
# Name: Engine HP, dtype: float64

# %%
df[['Make', 'Model']]
# Out:
#       Make     Model
# 0   Nissan    Stanza
# 1  Hyundai    Sonata
# 2    Lotus     Elise
# 3      GMC    Acadia
# 4   Nissan  Frontier

# %% [markdown]
# **To add column**

# %%
data = df.drop(columns=['S.N'])  #using column argument

# %%
df.drop(columns=['data'], inplace=True)

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %%
del df['id']     #directly delete a column

# %%
df
# Out:
#    S.N     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0    1   Nissan    Stanza  1991      138.0                 4
# 1    2  Hyundai    Sonata  2017        NaN                 4
# 2    3    Lotus     Elise  2010      218.0                 4
# 3    4      GMC    Acadia  2017      194.0                 4
# 4    5   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %% [markdown]
# **To add new columns**

# %%
new_columnn = [1,2,3,4,5]
data = df.insert(0, 'S.N', new_columnn)

# %%
df
# Out:
#    S.N     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0    1   Nissan    Stanza  1991      138.0                 4
# 1    2  Hyundai    Sonata  2017        NaN                 4
# 2    3    Lotus     Elise  2010      218.0                 4
# 3    4      GMC    Acadia  2017      194.0                 4
# 4    5   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP  id
# 0            MANUAL         sedan   2000   1
# 1         AUTOMATIC         Sedan  27150   2
# 2            MANUAL   convertible  54990   3
# 3         AUTOMATIC       4dr SUV  34450   4
# 4            MANUAL        Pickup  32340   5

# %% [markdown]
# # index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.loc[[1, 2]]
# Out:
#    S.N     Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1    2  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# 2    3    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 2   convertible  54990

# %%
df.index = ['a', 'b', 'c','d', 'e']
df
# Out:
#    S.N     Make     Model  Year  Engine HP  Engine Cylinders  \
# a    1   Nissan    Stanza  1991      138.0                 4
# b    2  Hyundai    Sonata  2017        NaN                 4
# c    3    Lotus     Elise  2010      218.0                 4
# d    4      GMC    Acadia  2017      194.0                 4
# e    5   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# a            MANUAL         sedan   2000
# b         AUTOMATIC         Sedan  27150
# c            MANUAL   convertible  54990
# d         AUTOMATIC       4dr SUV  34450
# e            MANUAL        Pickup  32340

# %%
df.loc['a', 'Make']
# Out:
# 'Nissan'

# %%
df.loc[df['S.N']>=1, ['Make', 'Model']]
# Out:
#       Make     Model
# a   Nissan    Stanza
# b  Hyundai    Sonata
# c    Lotus     Elise
# d      GMC    Acadia
# e   Nissan  Frontier

# %%
df.iloc[0:2]
# Out:
#    S.N     Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a    1   Nissan  Stanza  1991      138.0                 4            MANUAL
# b    2  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150

# %% [markdown]
# **Reset index**

# %%
df.reset_index()
# Out:
#   index  S.N     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a    1   Nissan    Stanza  1991      138.0                 4
# 1     b    2  Hyundai    Sonata  2017        NaN                 4
# 2     c    3    Lotus     Elise  2010      218.0                 4
# 3     d    4      GMC    Acadia  2017      194.0                 4
# 4     e    5   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %%
df.reset_index(drop=True)
# Out:
#    S.N     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0    1   Nissan    Stanza  1991      138.0                 4
# 1    2  Hyundai    Sonata  2017        NaN                 4
# 2    3    Lotus     Elise  2010      218.0                 4
# 3    4      GMC    Acadia  2017      194.0                 4
# 4    5   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %%
df
# Out:
#    S.N     Make     Model  Year  Engine HP  Engine Cylinders  \
# a    1   Nissan    Stanza  1991      138.0                 4
# b    2  Hyundai    Sonata  2017        NaN                 4
# c    3    Lotus     Elise  2010      218.0                 4
# d    4      GMC    Acadia  2017      194.0                 4
# e    5   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# a            MANUAL         sedan   2000
# b         AUTOMATIC         Sedan  27150
# c            MANUAL   convertible  54990
# d         AUTOMATIC       4dr SUV  34450
# e            MANUAL        Pickup  32340

# %%
df = df.reset_index(drop=True)
df
# Out:
#    S.N     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0    1   Nissan    Stanza  1991      138.0                 4
# 1    2  Hyundai    Sonata  2017        NaN                 4
# 2    3    Lotus     Elise  2010      218.0                 4
# 3    4      GMC    Acadia  2017      194.0                 4
# 4    5   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %% [markdown]
# # Element-wise operations

# %%
df['Engine HP']/100
# Out:
# 0    1.38
# 1     NaN
# 2    2.18
# 3    1.94
# 4    2.61
# Name: Engine HP, dtype: float64

# %%
df['Year']>=2017
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Year, dtype: bool

# %% [markdown]
# **Filtering**

# %%
df[
    df['Year']>=2015
]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df[
    (df['Make']=='Nissan') & (df['Year']>=2015)
]
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 4        Pickup  32340

# %% [markdown]
# **Sring Operations**

# %%
df['Vehicle_Style'].str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.replace(' ', '_').str.lower()
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340

# %% [markdown]
# **Summarizing Operations**

# %%
df.MSRP.max()
# Out:
# 54990

# %%
df.MSRP.describe()
# Out:
# count        5.000000
# mean     30186.000000
# std      18985.044904
# min       2000.000000
# 25%      27150.000000
# 50%      32340.000000
# 75%      34450.000000
# max      54990.000000
# Name: MSRP, dtype: float64

# %%
df.describe()
# Out:
#               Year  Engine HP  Engine Cylinders          MSRP
# count     5.000000    4.00000          5.000000      5.000000
# mean   2010.400000  202.75000          4.400000  30186.000000
# std      11.260551   51.29896          0.894427  18985.044904
# min    1991.000000  138.00000          4.000000   2000.000000
# 25%    2010.000000  180.00000          4.000000  27150.000000
# 50%    2017.000000  206.00000          4.000000  32340.000000
# 75%    2017.000000  228.75000          4.000000  34450.000000
# max    2017.000000  261.00000          6.000000  54990.000000

# %%
df.nunique()
# Out:
# Make                 4
# Model                5
# Year                 3
# Engine HP            4
# Engine Cylinders     2
# Transmission Type    2
# Vehicle_Style        4
# MSRP                 5
# dtype: int64

# %% [markdown]
# **Missing Values**

# %%
df.isnull()
# Out:
#     Make  Model   Year  Engine HP  Engine Cylinders  Transmission Type  \
# 0  False  False  False      False             False              False
# 1  False  False  False       True             False              False
# 2  False  False  False      False             False              False
# 3  False  False  False      False             False              False
# 4  False  False  False      False             False              False
#
#    Vehicle_Style   MSRP
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            1
# Engine Cylinders     0
# Transmission Type    0
# Vehicle_Style        0
# MSRP                 0
# dtype: int64

# %% [markdown]
# **Grouping**
#
# ```
# SELECT
#     transmission_type,
#     AVG(MSRP)
# FROM
#     cars
# GROUP BY
#     transmission_type
# ```

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
df.groupby('Transmission Type').MSRP.mean()
# Out:
# Transmission Type
# AUTOMATIC    30800.000000
# MANUAL       29776.666667
# Name: MSRP, dtype: float64

# %%
df.to_dict(orient='records')
# Out:
# [{'Make': 'Nissan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 2000},
#  {'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 27150},
#  {'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'convertible',
#   'MSRP': 54990},
#  {'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': '4dr_suv',
#   'MSRP': 34450},
#  {'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'pickup',
# ...
